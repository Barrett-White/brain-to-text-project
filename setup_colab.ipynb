# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/Sean0418/brain-to-text-project.git
# Out:
# fatal: destination path 'brain-to-text-project' already exists and is not an empty directory.

# %%
# If needed, you can pull here
# !git pull
# Out:
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9 (delta 5), reused 7 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (9/9), 2.68 KiB | 305.00 KiB/s, done.
# From https://github.com/Sean0418/brain-to-text-project
#    31d36c7..18e705e  sean       -> origin/sean
# Updating 31d36c7..18e705e
# Fast-forward
#  baseline/rnn_args.yaml |  74 ++++++++++++++++++++-
#  requirements.txt       | 177 +++++++++++++++++++++++++++++++++++++++++++++++++
#  2 files changed, 250 insertions(+), 1 deletion(-)
#  create mode 100644 requirements.txt

# %%
# %cd brain-to-text-project/
# Out:
# [Errno 2] No such file or directory: 'brain-to-text-project/'
# /content/brain-to-text-project/brain-to-text-project

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
from cnn_transformer_model.transformer_trainer import BrainToTextDecoder_Trainer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3876712836.py in <cell line: 0>()
# ----> 1 from cnn_transformer_model.transformer_trainer import BrainToTextDecoder_Trainer
#
# /content/brain-to-text-project/cnn_transformer_model/transformer_trainer.py in <module>
#      15 from torch.optim.lr_scheduler import LambdaLR
#      16 from torch.utils.data import DataLoader
# ---> 17 from transformer_model import TransformerDecoder
#      18
#      19 from baseline.data_augmentations import gauss_smooth
#
# ModuleNotFoundError: No module named 'transformer_model'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
